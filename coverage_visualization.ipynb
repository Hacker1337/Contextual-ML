# %%
import jax
import jax.numpy as jnp
from jax import device_put

# %%
import pennylane as qml
import numpy as np
from IPython import display
import time
import matplotlib.pyplot as plt
from math import sqrt,pi
from tqdm import tqdm
from itertools import product
import matplotlib.pyplot as plt
import optax

# %%
#seeds used for random functions
from jax import random
key = random.PRNGKey(999)
np.random.seed(999)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# # data generation: rps model

# %% [markdown]
# Below we generate the RPS data set as described in the manuscript.

# %% [markdown]
# first we construct a 'points' matricies for each pair of players, where a point is awarded if a player beats another and deducted if they are beaten: `A[i,j]` gives the points awarded to player i when playing player j for each of the 9 possible pairs of actions.

# %%
A=np.zeros([3,3,3,3])
A[0,1]=np.array([[1,-1,1],[1,-1,-1],[-1,1,0]])
A[0,2]=np.array([[1,-1,1],[1,0,-1],[-1,1,-1]])
A[1,2]=np.array([[0,-1,1],[1,1,-1],[-1,1,-1]])
A[1,0]=-A[0,1].T
A[2,0]=-A[0,2].T
A[2,1]=-A[1,2].T
A = jnp.array(A)

# %%
def get_payoff_probs(X):
    """
    get the payoff probabilities for each player given a strategy X
    """
    points0 = jnp.matmul(jnp.matmul(X[0],A[0,1]),X[1])+jnp.matmul(jnp.matmul(X[0],A[0,2]),X[2])
    points1 = jnp.matmul(jnp.matmul(X[1],A[1,0]),X[0])+jnp.matmul(jnp.matmul(X[1],A[1,2]),X[2])
    points2 = jnp.matmul(jnp.matmul(X[2],A[2,0]),X[0])+jnp.matmul(jnp.matmul(X[2],A[2,1]),X[1])
    probs = jnp.array([points0,points1,points2])
    return (probs/2+1)/2

#JAX vectorisation
vpayoff_probs = jax.vmap(get_payoff_probs,0)

# %%
def get_strat_mat(N):
    """
    This generates N strategy matrices, normalised by row
    """
    pmat = np.random.rand(N,3,3)
    for i in range(N):
        for k in range(3):
            pmat[i,k]=pmat[i,k]/np.sum(pmat[i,k])
    return pmat

def generate_data(N):
    X = get_strat_mat(N) #strategies
    P = vpayoff_probs(X) #payoff probabilities
    r=np.random.rand(*P.shape) 
    Y = np.where(P>r,0,1) #sampled payoffs for data labels
    return X, Y, P

# %% [markdown]
# # Define learning models

# %% [markdown]
# Here we define the quantum and surrogate models

# %%
#some functions used to cosntruct the quantum models

def swap_rot(x,wires):
    #two qubit rotation with swap matrix as generator 
    #(identiy is not included since it adds a global phase)
    qml.PauliRot(x,'XX',wires=wires)
    qml.PauliRot(x,'YY',wires=wires)
    qml.PauliRot(x,'ZZ',wires=wires)
    
def data_encoding(x):
    #S_x^1 in paper
    for q in range(3):
        qml.RZ(x[q],wires=q)

def data_encoding_pairs(x):
    #S_x^2 in paper
    qml.PauliRot(x[0]*x[1],'ZZ',wires=[0,1])
    qml.PauliRot(x[1]*x[2],'ZZ',wires=[1,2])
    qml.PauliRot(x[0]*x[2],'ZZ',wires=[0,2])
    
def state_prep(alpha):
    #V in paper for biased model
    qml.RY(alpha[0],wires=0)
    qml.RY(alpha[0]+pi,wires=1) 
    
def layer_q(weights,blocks):
    #U in paper for the biased model
    for b in range(blocks):
        for q in range(3):
            qml.RZ(weights[b,q],wires=q)
            qml.PauliRot(weights[b,3],'ZZ',wires=[0,1])
            qml.PauliRot(weights[b,4],'ZZ',wires=[0,2])
            qml.PauliRot(weights[b,5],'ZZ',wires=[1,2])
        swap_rot(weights[b,6],wires=[0,1])
        swap_rot(weights[b,7],wires=[1,2])
        swap_rot(weights[b,8],wires=[0,2])
        
def layer_u(weights,blocks):
    #U in paper for the unbiased model
    for b in range(blocks):
        for q in range(3):
            qml.Rot(weights[b,3*q],weights[b,3*q+1],weights[b,3*q+2],wires=q)
        qml.CNOT(wires=[0,1])
        qml.CNOT(wires=[0,1])
        qml.CNOT(wires=[0,1])

# %% [markdown]
# ## Quantum models

# %% [markdown]
# Define the two quantum model classes (biased and unbiased)

# %%
def get_q_model(basic=False):
    #The biased quantum model
    dev = qml.device('default.qubit',wires=3)
    @qml.qnode(dev, interface="jax")
    def model(weights,x,layers,blocks):
        qml.Hadamard(wires=0)
        qml.Hadamard(wires=1)
        qml.Hadamard(wires=2)
        #we use the last layer of the weights array to store the parameter V
        state_prep(weights[2*layers+1,0])
        x1 = jnp.array([x[0,0],x[1,1],x[2,2]])
        x2 = jnp.array(([x[0,1]-x[0,2],x[1,2]-x[1,0],x[2,0]-x[2,1]]))
        for l in range(0,2*layers,2):
            layer_q(weights[l],blocks)
            data_encoding(x1)
            layer_q(weights[l+1],blocks)
            data_encoding_pairs(x2)
        layer_q(weights[2*layers],blocks)
        return [qml.expval(qml.PauliZ(0)),qml.expval(qml.PauliZ(1)),qml.expval(qml.PauliZ(2))]
    #jax vectorisation, we vectorise over the data input (the second argument)
    vmodel = jax.vmap(model,(None,0,None,None))
    def vmodel_fixed(*args):
        return jnp.array(vmodel(*args)).T 
    return vmodel_fixed

def get_q_model_unstr(basic=False):
    #The unbiased quantum model
    dev = qml.device('default.qubit',wires=3)
    @qml.qnode(dev, interface="jax")
    def model(weights,x,layers,blocks):
        x1 = jnp.array([x[0,0],x[1,1],x[2,2]])
        x2 = jnp.array([x[0,1]-x[0,2],x[1,2]-x[1,0],x[2,0]-x[2,1]])
        for l in range(0,layers*2,2):
            layer_u(weights[l],blocks)
            data_encoding(x1)
            layer_u(weights[l+1],blocks)
            data_encoding_pairs(x2)
        layer_u(weights[2*layers],blocks)
        return [qml.expval(qml.PauliZ(0)),qml.expval(qml.PauliZ(1)),qml.expval(qml.PauliZ(2))]
    vmodel = jax.vmap(model,(None,0,None,None))
    def vmodel_fixed(*args):
        return jnp.array(vmodel(*args)).T 
    return vmodel_fixed

# %% [markdown]
# ## Surroagte models

# %% [markdown]
# Define the surrogate model class

# %%
def get_freqs(nvars,spectrum):
        """
        Get the array of all possible frequencies omega appearing in the truncated fourier series
        Where the number of data variables is nvars, and the largest value of any component of 
        omega is spectrum. 
        """
        nlambda = 2*spectrum+1
        freqs= [jnp.unravel_index(i,[nlambda for __ in range(nvars)]) for i in range(nlambda**nvars)]
        freqs = jnp.array(freqs)
        freqs=freqs-spectrum
        return freqs

def get_surrogate_model():
    def surrogate(weights,x,freqs,arg2=0):
        x1 = jnp.array([x[0,0],x[1,1],x[2,2]])
        x2 = jnp.array([x[0,1]-x[0,2],x[1,2]-x[1,0],x[2,0]-x[2,1]])
        variables = jnp.concatenate((x1,
                                    jnp.array([x2[0]*x2[1] ,x2[1]*x2[2], x2[0]*x2[2]])))
        #get all the omega*x values appearing in the fourier sum
        z = jnp.sum(freqs*variables.flatten(),axis=1)
        waves_cos = jnp.cos(z)
        waves_sin = jnp.sin(z)
        #build the linear models for each component via matrix multiplication
        y=jnp.matmul(weights,jnp.hstack([waves_cos,waves_sin]))
        #below implements the hardtanh function
        signs = jnp.sign(y)
        y=jnp.abs(y)
        y=jnp.vstack([y,jnp.ones(3)])
        y=jnp.min(y,axis=0)
        y=y*signs
        return  y
    #JAX vectorisation
    vsurrogate = jax.vmap(surrogate,(None,0,None,None))

    return vsurrogate

# %% [markdown]
# Some functions used in training an evaluation

# %%
def kl_div(p,q):
    """
    Get the KL divergence between two probability distribtuions
    """
    p=jnp.vstack([p,jnp.ones(len(p))*10**(-8)]) #lower cutoff of prob values of 10e-8
    p=jnp.max(p,axis=0)
    return jnp.sum(q*jnp.log(q/p)) #forward kl div 

def kl_mean(probs,probs0):
    """
    get the mean KL divergence of the three marginal distributions
    """
    kl = 0
    for t in range(3):
        kl=kl+kl_div(probs[t,:],probs0[t,:])
    return kl/3

#vectorise kl_mean function, makes estimating the average KL diverence of a model faster.
vkl_mean = jax.vmap(kl_mean,(0,0))

def model_probs(model,X_test,weights,arg1,arg2):
    """
    Returns the marginal probabilties of a given model for a test data set X_test
    """
    probs = np.zeros([len(X_test),3,2])
    expvals = model(weights,X_test,arg1,arg2)
    for t in range(3):
        probs[:,t,0] = (1+expvals[:,t])/2
        probs[:,t,1] = (1-expvals[:,t])/2
    return probs

def likelihood(weights,X,Y,model,arg1,arg2,reg):
    """
    The cost function. Returns the negative log likelihood plus a L2  weight regularisation penalty
    """
    expvals = model(weights,X,arg1,arg2)
    probs = (1+(1-2*Y)*expvals)/2
    probs = jnp.log(probs)
    llh = jnp.sum(probs)/len(X)/3
    return -llh + jnp.sum(weights**2)*reg

def gen_test_set(N_test):
    """
    generates a test set of strategies
    """
    X_test = get_strat_mat(N_test)
    return X_test

def get_av_test_kl(model,weights,probs0,X_test,arg1,arg2):
    """
    returns the average KL divergence of a model for a test set X_test. 
    This is the figure of merit used to evaluate the generalisation performance.
    """
    N_test=len(X_test)
    probs = np.zeros(probs0.shape)
    expvals = model(weights,X_test,arg1,arg2)
    for t in range(3):
        probs[:,t,0] = (1+expvals[:,t])/2
        probs[:,t,1] = (1-expvals[:,t])/2
    return np.sum(vkl_mean(probs,probs0))/N_test

# %% [markdown]
# We use the optax library to optimise the models. For the quanutm model arg1 and arg2 correspond to L and B in the paper. For the surrogate model arg1 is an array containing all values of omega, and arg2 is unused.

# %%
def optimise_model_adam(model,nstep,lr,weights,batchfrac=1.0,sgd=False,arg1=1,arg2=1,reg=0.):
    plot=[[],[],[]]
    X_test = gen_test_set(10000) #the test set for evaluation
    N_test=len(X_test)
    probs0 = np.zeros([N_test,3,2])
    probs0[:,:,0] = vpayoff_probs(X_test) #the true probabilities for the test set
    probs0[:,:,1] = 1-probs0[:,:,0]
    probs0=jnp.array(probs0)
    if sgd:
        optimizer = optax.sgd(lr)
    else:
        optimizer = optax.adam(lr) #this is default
    opt_state = optimizer.init(weights)
    steps = tqdm(range(nstep))
    for step in steps:
        #use optax to update parameters
        llh, grads = jax.value_and_grad(likelihood)(weights, X, Y, model,arg1,arg2,reg)
        updates, opt_state = optimizer.update(grads, opt_state, weights)
        weights = optax.apply_updates(weights, updates)
        if step%1==0:
            kl = get_av_test_kl(model,weights,probs0,X_test,arg1,arg2)
            steps.set_description("Current divergence: %s" % str(kl)+ " :::: "+
                                  "Current likelihood: %s" % str(llh))
        plot[0].append(step)
        plot[1].append(float(llh))
        plot[2].append(float(kl))
    return weights, llh, kl, plot

# %% [markdown]
# # Training

# %%
#generate data
N=1500 #number of data points

X = np.load('Xdata.npy')
Y = np.load('Ydata.npy')

X = jnp.array(X)
Y = jnp.array(Y)
# P = jnp.array(P)

X_copy = jnp.array(X)

#scale the data by pi/2
scaling = pi/2
X = scaling*jnp.array(X_copy)

#put the data on the GPU if there is one
X = device_put(X)
Y = device_put(Y)

# %%
n_steps = 2000 #number of optimisation steps
n_runs = 1 #number of runs (or trials)

layers_list = [2] #the possible values of L we consider for the quantum models
spectrum_list = [2] #the possible spectra we consider for the surrogate
reg = 0. #the L2 weight regularisation penalty coefficient
nvars=6 #the number of data variables in the fourier series of the surrogate model
blocks = 2 #the value of B in the paper

#arrays for storing the plot data
data_q = [np.zeros([n_runs,n_steps,3]) for __ in range(len(layers_list))]
data_u = [np.zeros([n_runs,n_steps,3]) for __ in range(len(layers_list))]
data_s = [np.zeros([n_runs,n_steps,3]) for __ in range(len(spectrum_list))]

# %% [markdown]
# ## Train the models

# %% [markdown]
# ### surragate model

# %%
for i,spectrum in enumerate(spectrum_list):
    n_freq = 2*(2*spectrum+1)**6
    freqs= get_freqs(nvars,spectrum)
    if spectrum==1:
        lr=0.001
    else:
        lr=0.0001
    vsurrogate = get_surrogate_model()
    vsurrogate=jax.jit(vsurrogate)
    for run in range(n_runs):
        weights_s = (2*np.random.rand(3,n_freq)-1)*1/n_freq
        weights_s = device_put(weights_s)
        weights_s, llh, kl, plot = optimise_model_adam(vsurrogate,50,lr,weights_s,sgd=True,arg1=freqs,arg2=0,reg=reg)
        data_s[i][run,:,0]=plot[0]
        data_s[i][run,:,1]=plot[1]
        data_s[i][run,:,2]=plot[2]

np.save('data_s',np.array(data_s))
# Out:
# Current divergence: 0.006944343 :::: Current likelihood: 0.682019: 100%|██████████| 50/50 [00:57<00:00,  1.16s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 14
#      12 weights_s = device_put(weights_s)
#      13 weights_s, llh, kl, plot = optimise_model_adam(vsurrogate,50,lr,weights_s,sgd=True,arg1=freqs,arg2=0,reg=reg)
# ---> 14 data_s[i][run,:,0]=plot[0]
#      15 data_s[i][run,:,1]=plot[1]
#      16 data_s[i][run,:,2]=plot[2]
#
# ValueError: could not broadcast input array from shape (50,) into shape (2000,)

# %% [markdown]
# ### Quantum models

# %% [markdown]
# Quatum biased bodel

# %%
for i,lay in enumerate(layers_list):
    layers=lay
    vmodel=get_q_model()
    vmodel=jax.jit(vmodel,static_argnums=[2,3])
    for run in range(n_runs):
        weights_q = np.random.rand(2*layers+2,blocks,9)*2*pi
        weights_q = device_put(weights_q)
        args = weights_q, X, Y,layers,blocks
        # print("vmodel:", vmodel(args), '\n' "model:", model(args))
        weights_q, llh, kl, plot = optimise_model_adam(vmodel,n_steps,.001,weights_q,sgd=False,arg1=layers,arg2=blocks)
        data_q[i][run,:,0]=plot[0]
        data_q[i][run,:,1]=plot[1]
        data_q[i][run,:,2]=plot[2]
                
np.save('data_q',np.array(data_q))
# Out:
#   0%|          | 0/50 [00:22<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 10
#       8 args = weights_q, X, Y,layers,blocks
#       9 # print("vmodel:", vmodel(args), '\n' "model:", model(args))
# ---> 10 weights_q, llh, kl, plot = optimise_model_adam(vmodel,50,.001,weights_q,sgd=False,arg1=layers,arg2=blocks)
#      11 data_q[i][run,:,0]=plot[0]
#      12 data_q[i][run,:,1]=plot[1]
#
# Cell In[11], line 17, in optimise_model_adam(model, nstep, lr, weights, batchfrac, sgd, arg1, arg2, reg)
#      14 steps = tqdm(range(nstep))
#      15 for step in steps:
#      16     #use optax to update parameters
# ---> 17     llh, grads = jax.value_and_grad(likelihood)(weights, X, Y, model,arg1,arg2,reg)
#      18     updates, opt_state = optimizer.update(grads, opt_state, weights)
#      19     weights = optax.apply_updates(weights, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/api.py:1242, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#    1240   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#    1241 if not has_aux:
# -> 1242   ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#    1243 else:
#    1244   ans, vjp_py, aux = _vjp(
#    1245       f_partial, *dyn_args, has_aux=True, reduce_axes=reduce_axes)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/api.py:2780, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2778 if not has_aux:
#    2779   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2780   out_primal, out_vjp = ad.vjp(
#    2781       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2782   out_tree = out_tree()
#    2783 else:
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:137, in vjp(traceable, primals, has_aux, reduce_axes)
#     135 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     136   if not has_aux:
# --> 137     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     138   else:
#     139     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:126, in linearize(traceable, *primals, **kwargs)
#     124 _, in_tree = tree_flatten(((primals, primals), {}))
#     125 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 126 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     127 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     128 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:770, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     768 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     769   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 770   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     771   assert not env
#     772   del main, fun, env
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/linear_util.py:165, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     162 gen = gen_static_args = out_store = None
#     164 try:
# --> 165   ans = self.f(*args, **dict(self.params, **kwargs))
#     166 except:
#     167   # Some transformations yield from inside context managers, so we have to
#     168   # interrupt them before reraising the exception. Otherwise they will only
#     169   # get garbage-collected at some later time, running their cleanup tasks
#     170   # only after this exception is handled, which can corrupt the global
#     171   # state.
#     172   while stack:
#
# Cell In[10], line 36, in likelihood(weights, X, Y, model, arg1, arg2, reg)
#      32 def likelihood(weights,X,Y,model,arg1,arg2,reg):
#      33     """
#      34     The cost function. Returns the negative log likelihood plus a L2  weight regularisation penalty
#      35     """
# ---> 36     expvals = model(weights,X,arg1,arg2)
#      37     probs = (1+(1-2*Y)*expvals)/2
#      38     probs = jnp.log(probs)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/api.py:698, in _cpp_jit.<locals>.cache_miss(*args, **kwargs)
#     695   out_flat = call_bind_continuation(execute(*args_flat))
#     696 else:
#     697   out_flat = call_bind_continuation(
# --> 698       top_trace.process_call(primitive, fun_, tracers, params))
#     699 out_pytree_def = out_tree()
#     700 out = tree_unflatten(out_pytree_def, out_flat)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:341, in JVPTrace.process_call(self, call_primitive, f, tracers, params)
#     339 update_params = call_param_updaters.get(call_primitive)
#     340 new_params = update_params(params, which_nz) if update_params else params
# --> 341 result = call_primitive.bind(_update_annotation(f_jvp, f.in_type, which_nz),
#     342                              *args, **new_params)
#     343 primal_out, tangent_out = tree_unflatten(out_tree(), result)
#     344 tangent_out = [Zero(get_aval(p).at_least_vspace()) if t is None else t
#     345                for p, t in zip(primal_out, tangent_out)]
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/core.py:2065, in CallPrimitive.bind(self, fun, *args, **params)
#    2062 def bind(self, fun, *args, **params):
#    2063   call_bind_continuation, top_trace, fun_, tracers, params = (
#    2064       call_bind_with_continuation(self, fun, *args, **params))
# -> 2065   outs = top_trace.process_call(self, fun_, tracers, params)
#    2066   return call_bind_continuation(outs)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:268, in JaxprTrace.process_call(self, primitive, f, tracers, params)
#     265 const_params = update_params(params, in_knowns, 0)
#     267 # Run the call, getting known out vals and aux data used for staged-out call
# --> 268 out = primitive.bind(_update_annotation_known(f_, f.in_type, in_knowns),
#     269                      *in_consts, **const_params)
#     270 fwds, out_knowns, out_type, jaxpr, env = aux()
#     271 # Split apart known outputs from the original call and non-fwded residuals.
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/core.py:2065, in CallPrimitive.bind(self, fun, *args, **params)
#    2062 def bind(self, fun, *args, **params):
#    2063   call_bind_continuation, top_trace, fun_, tracers, params = (
#    2064       call_bind_with_continuation(self, fun, *args, **params))
# -> 2065   outs = top_trace.process_call(self, fun_, tracers, params)
#    2066   return call_bind_continuation(outs)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/core.py:731, in EvalTrace.process_call(self, primitive, f, tracers, params)
#     730 def process_call(self, primitive, f, tracers, params):
# --> 731   return primitive.impl(f, *tracers, **params)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/dispatch.py:246, in _xla_call_impl(fun, device, backend, name, donated_invars, inline, keep_unused, *args)
#     244 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name,
#     245                    donated_invars, inline, keep_unused: bool):
# --> 246   compiled_fun = _xla_call_impl_lazy(
#     247       fun,
#     248       *args,
#     249       device=device,
#     250       backend=backend,
#     251       name=name,
#     252       donated_invars=donated_invars,
#     253       inline=inline,
#     254       keep_unused=keep_unused)
#     255   # TODO(parkers): Maybe apply this more generally in the case of the c++
#     256   # fallback.
#     257   try:
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/dispatch.py:240, in _xla_call_impl_lazy(***failed resolving arguments***)
#     238     raise NotImplementedError('Dynamic shapes do not work with Array.')
#     239   arg_specs = [(None, getattr(x, '_device', None)) for x in args]
# --> 240 return xla_callable(fun, device, backend, name, donated_invars, keep_unused,
#     241                     *arg_specs)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/linear_util.py:301, in cache.<locals>.memoized_fun(fun, *args)
#     299   fun.populate_stores(stores)
#     300 else:
# --> 301   ans = call(fun, *args)
#     302   cache[key] = (ans, fun.stores)
#     304 return ans
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/dispatch.py:354, in _xla_callable_uncached(fun, device, backend, name, donated_invars, keep_unused, *arg_specs)
#     351   computation = sharded_lowering(fun, device, backend, name, donated_invars,
#     352                                  False, keep_unused, *arg_specs)
#     353   allow_prop = [True] * len(computation.compile_args['global_out_avals'])
# --> 354   return computation.compile(_allow_propagation_to_outputs=allow_prop).unsafe_call
#     355 else:
#     356   return lower_xla_callable(fun, device, backend, name, donated_invars, False,
#     357                             keep_unused, *arg_specs).compile().unsafe_call
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:3203, in MeshComputation.compile(self, _allow_propagation_to_outputs, _allow_compile_replicated)
#    3199 def compile(self,
#    3200             _allow_propagation_to_outputs: Optional[Sequence[bool]] = None,
#    3201             _allow_compile_replicated: bool = True) -> MeshExecutable:
#    3202   if self._executable is None:
# -> 3203     executable = self._compile_unloaded(
#    3204         _allow_propagation_to_outputs, _allow_compile_replicated)
#    3205     if isinstance(executable, UnloadedMeshExecutable):
#    3206       executable = executable.load()
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:3174, in MeshComputation._compile_unloaded(self, _allow_propagation_to_outputs, _allow_compile_replicated)
#    3172   return MeshExecutable.from_trivial_jaxpr(**self.compile_args)
#    3173 else:
# -> 3174   return UnloadedMeshExecutable.from_hlo(
#    3175       self._name,
#    3176       self._hlo,
#    3177       **self.compile_args,
#    3178       _allow_propagation_to_outputs=_allow_propagation_to_outputs,
#    3179       _allow_compile_replicated=_allow_compile_replicated)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:3456, in UnloadedMeshExecutable.from_hlo(name, computation, mesh, global_in_avals, global_out_avals, in_shardings, out_shardings, spmd_lowering, tuple_args, in_is_global, auto_spmd_lowering, _allow_propagation_to_outputs, _allow_compile_replicated, unordered_effects, ordered_effects, host_callbacks, keepalive, kept_var_idx, backend, device_assignment, committed, pmap_nreps)
#    3452 else:
#    3453   with dispatch.log_elapsed_time(f"Finished XLA compilation of {name} "
#    3454                                  "in {elapsed_time} sec",
#    3455                                  event=dispatch.BACKEND_COMPILE_EVENT):
# -> 3456     xla_executable = dispatch.compile_or_get_cached(
#    3457         backend, computation, compile_options, host_callbacks)
#    3459   if auto_spmd_lowering:
#    3460     assert mesh is not None
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/dispatch.py:1081, in compile_or_get_cached(backend, computation, compile_options, host_callbacks)
#    1077     _cache_write(serialized_computation, compile_time, module_name,
#    1078                  compile_options, backend, compiled, host_callbacks)
#    1079     return compiled
# -> 1081 return backend_compile(backend, serialized_computation, compile_options,
#    1082                        host_callbacks)
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/miniconda3/envs/pl_jax_1/lib/python3.10/site-packages/jax/_src/dispatch.py:1026, in backend_compile(backend, built_c, options, host_callbacks)
#    1021   return backend.compile(built_c, compile_options=options,
#    1022                          host_callbacks=host_callbacks)
#    1023 # Some backends don't have `host_callbacks` option yet
#    1024 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#    1025 # to take in `host_callbacks`
# -> 1026 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %% [markdown]
# Quantum unbiased model

# %%
for i,lay in enumerate(layers_list):
    layers=lay
    vmodel_unstr = get_q_model_unstr()
    vmodel_unstr = jax.jit(vmodel_unstr,static_argnums=[2,3])
    for run in range(n_runs):
        weights_u = np.random.rand(2*layers+1,blocks,9)*2*pi
        weights_u = device_put(weights_u)
        weights_u, llh, kl, plot = optimise_model_adam(vmodel_unstr,n_steps,.001,weights_u,sgd=False,arg1=layers,arg2=blocks)
        data_u[i][run,:,0]=plot[0]
        data_u[i][run,:,1]=plot[1]
        data_u[i][run,:,2]=plot[2]
        
np.save('data_u',np.array(data_u))
# Out:
# Current divergence: 0.010024494 :::: Current likelihood: 0.68425053: 100%|██████████| 2000/2000 [04:10<00:00,  7.99it/s]

# %% [markdown]
# ## Visualization of coverage of output space by different models

# %%
# np.save("weights_s", weights_s) # s model halted on min loss
# np.save("weights_q", weights_q)
# np.save("weights_u", weights_u)

# %%
def visual_output(model, weights, arg1=2, arg2=2):
    probs = np.zeros([len(X),3])
    expvals = model(weights,X,arg1,arg2)
    
    for t in range(3):
        probs[:,t] = (1+expvals[:,t])/2
    
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    ax.scatter(probs[:, 0], probs[:, 1], probs[:, 2])
    ax.view_init(None, 45)

    plt.show()

# %%
visual_output(vsurrogate, weights_s, arg1=freqs, arg2=0)

# %%
visual_output(vmodel, weights_q)

# %%
visual_output(vmodel_unstr, weights_u)

# %% [markdown]
# ## Contextuality consequences
#
# In the following plots red dots indicate the borders of the area of possible answers, and yellow ones indicate the borders of inner hexagon 1.5 times smaller, which theoretically can not be covered by the uncontextual model.
# ![image.png](attachment:image.png)

# %%
import itertools


def visual_projection(model, weights, arg1=2, arg2=2, title=None):
    '''visualizes projection of output 3d point on 2d surface with sum of probabilities = const'''
    probs = np.zeros([len(X),3])
    expvals = model(weights,X,arg1,arg2)
    v1 = np.array([-1/sqrt(2), 1/sqrt(2), 0])
    v2 = np.array([-1/sqrt(6), -1/sqrt(6), 2/sqrt(6)])
    for t in range(3):
        probs[:,t] = (1+expvals[:,t])/2
    x = np.einsum("ji,i->j", probs, v1)    
    y = np.einsum("ji,i->j", probs, v2)    
    plt.scatter(x, y)
    borders = np.array(
        list(itertools.permutations([1, 0.5, 0]))
    )
    x = np.einsum("ji,i->j", borders, v1)    
    y = np.einsum("ji,i->j", borders, v2)   
    plt.scatter(x, y, c='red')
    alpha = 0.67
    plt.scatter(x*alpha, y*alpha, c='orange')
    plt.title(title)
    plt.show()

# %%
visual_projection(vsurrogate, weights_s, arg1=freqs, arg2=0, title="surragate model")
visual_projection(vmodel, weights_q, title="biased model")
visual_projection(vmodel_unstr, weights_u, title="unbiased model")
# Out:
# (6,) (6,)
# (6,) (6,)
# (6,) (6,)

# %% [markdown]
# (here, the surrogate model is trained to its minimum in los on a test sample. If you continue to train, all values regress to one point - the center)

# %%
def visual_projection(model, weights, arg1=2, arg2=2, title=None):
    '''visualizes projection of output 3d point on 2d surface with sum of probabilities = const'''
    probs = np.zeros([len(X),3])
    expvals = model(weights,X,arg1,arg2)
    v1 = np.array([-1/sqrt(2), 1/sqrt(2), 0])
    v2 = np.array([-1/sqrt(6), -1/sqrt(6), 2/sqrt(6)])
    for t in range(3):
        probs[:,t] = (1+expvals[:,t])/2
    x = np.einsum("ji,i->j", probs, v1)    
    y = np.einsum("ji,i->j", probs, v2)    
    plt.scatter(x, y)
    borders = np.array(
        list(itertools.permutations([1, 0.5, 0]))
    )
    x = np.einsum("ji,i->j", borders, v1)    
    y = np.einsum("ji,i->j", borders, v2)   
    
    plt.scatter(x, y, c='red')
    alpha = 0.67
    plt.scatter(x*alpha, y*alpha, c='orange')
    
    x = np.einsum("ji,i->j", Y, v1)    
    y = np.einsum("ji,i->j", Y, v2)   
    
    plt.scatter(x, y, c='red')
    plt.scatter(x, y, c='green')
    
    
    plt.title(title)
    plt.show()

# %%
visual_projection(vsurrogate, weights_s, arg1=freqs, arg2=0, title="surragate model")
visual_projection(vmodel, weights_q, title="biased model")
visual_projection(vmodel_unstr, weights_u, title="unbiased model")

# %%
uniq = np.unique(Y, axis=0).tolist()

ind = [uniq.index(y_.tolist()) for y_ in Y]

# %%
plt.hist(ind, bins=len(uniq))
plt.xticks(range(len(uniq)), uniq)
# Out:
# ([<matplotlib.axis.XTick at 0x7f14fff26650>,
#   <matplotlib.axis.XTick at 0x7f14fff26170>,
#   <matplotlib.axis.XTick at 0x7f14fff266b0>,
#   <matplotlib.axis.XTick at 0x7f14fff25030>,
#   <matplotlib.axis.XTick at 0x7f14ffb6f970>,
#   <matplotlib.axis.XTick at 0x7f14ffb9ca00>,
#   <matplotlib.axis.XTick at 0x7f14ffb9d1e0>,
#   <matplotlib.axis.XTick at 0x7f14ffb6f5e0>],
#  [Text(0, 0, '[0, 0, 0]'),
#   Text(1, 0, '[0, 0, 1]'),
#   Text(2, 0, '[0, 1, 0]'),
#   Text(3, 0, '[0, 1, 1]'),
#   Text(4, 0, '[1, 0, 0]'),
#   Text(5, 0, '[1, 0, 1]'),
#   Text(6, 0, '[1, 1, 0]'),
#   Text(7, 0, '[1, 1, 1]')])

# %%
y_probs = vpayoff_probs(X)
y_probs
# Out:
# Array([[0.86548597, 0.16572389, 0.46879017],
#        [0.38009125, 0.5598398 , 0.56006896],
#        [0.7589659 , 0.27128696, 0.4697471 ],
#        ...,
#        [0.57721335, 0.39585286, 0.5269338 ],
#        [0.626602  , 0.3359747 , 0.5374233 ],
#        [0.44418937, 0.59450746, 0.4613032 ]], dtype=float32)

# %%
v1 = np.array([-1/sqrt(2), 1/sqrt(2), 0])
v2 = np.array([-1/sqrt(6), -1/sqrt(6), 2/sqrt(6)])

x = np.einsum("ji,i->j", y_probs, v1)    
y = np.einsum("ji,i->j", y_probs, v2)    
plt.scatter(x, y)

borders = np.array(
    list(itertools.permutations([1, 0.5, 0]))
)
x = np.einsum("ji,i->j", borders, v1)    
y = np.einsum("ji,i->j", borders, v2)   

plt.scatter(x, y, c='red')
alpha = 0.67
plt.scatter(x*alpha, y*alpha, c='orange')

x = np.einsum("ji,i->j", Y, v1)    
y = np.einsum("ji,i->j", Y, v2)   

plt.scatter(x, y, c='red')
plt.scatter(x, y, c='green')

# %%
np.sum(y_probs, axis=1)
# Out:
# Array([1.5000001, 1.5      , 1.5      , ..., 1.5      , 1.5      ,
#        1.5      ], dtype=float32)

# %%
np.min(y_probs)
# Out:
# Array(-0.25632143, dtype=float32)

# %%
plt.hist(y_probs.flatten())
# Out:
# (array([  11.,   50.,  249.,  711., 1754., 1220.,  362.,   97.,   39.,
#            7.]),
#  array([-0.25632143, -0.09627759,  0.06376624,  0.22381008,  0.38385391,
#          0.54389775,  0.70394158,  0.86398542,  1.02402925,  1.18407309,
#          1.34411693]),
#  <BarContainer object of 10 artists>)

# %%
X_test = gen_test_set(10000) #the test set for evaluation
N_test=len(X_test)
probs0 = np.zeros([N_test,3])
probs0[:,:] = vpayoff_probs(X_test) #the true probabilities for the test set

# %%
X.sum(axis=2)
# Out:
# Array([[1.5707965, 1.5707964, 1.5707965],
#        [1.5707964, 1.5707965, 1.5707963],
#        [1.5707964, 1.5707963, 1.5707963],
#        ...,
#        [1.5707964, 1.5707963, 1.5707964],
#        [1.5707964, 1.5707965, 1.5707963],
#        [1.5707964, 1.5707964, 1.5707964]], dtype=float32)

# %%
plt.figure(figsize=(5, 5))
y_probs = vpayoff_probs(X_authors)
v1 = np.array([-1/sqrt(2), 1/sqrt(2), 0])
v2 = np.array([-1/sqrt(6), -1/sqrt(6), 2/sqrt(6)])

x = np.einsum("ji,i->j", y_probs, v1)    
y = np.einsum("ji,i->j", y_probs, v2)    
plt.scatter(x, y)

borders = np.array(
    list(itertools.permutations([1, 0.5, 0]))
)
x = np.einsum("ji,i->j", borders, v1)    
y = np.einsum("ji,i->j", borders, v2)   

plt.scatter(x, y, c='red')
alpha = 0.67
plt.scatter(x*alpha, y*alpha, c='orange')

x = np.einsum("ji,i->j", Y, v1)    
y = np.einsum("ji,i->j", Y, v2)   

plt.scatter(x, y, c='red')
plt.scatter(x, y, c='green')

# %%
X_test = gen_test_set(1000_000)

plt.figure(figsize=(5, 5))
y_probs = vpayoff_probs(X_test)
v1 = np.array([-1/sqrt(2), 1/sqrt(2), 0])
v2 = np.array([-1/sqrt(6), -1/sqrt(6), 2/sqrt(6)])

x = np.einsum("ji,i->j", y_probs, v1)    
y = np.einsum("ji,i->j", y_probs, v2)    
plt.scatter(x, y)

borders = np.array(
    list(itertools.permutations([1, 0.5, 0]))
)
x = np.einsum("ji,i->j", borders, v1)    
y = np.einsum("ji,i->j", borders, v2)   

plt.scatter(x, y, c='red')
alpha = 0.67
plt.scatter(x*alpha, y*alpha, c='orange')

x = np.einsum("ji,i->j", Y, v1)    
y = np.einsum("ji,i->j", Y, v2)   

plt.scatter(x, y, c='red')
plt.scatter(x, y, c='green')
